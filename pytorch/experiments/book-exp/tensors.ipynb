# %%
import torch

# %%
a = torch.ones(3)
a
# Out:
# tensor([1., 1., 1.])

# %%
a[1]
# Out:
# tensor(1.)

# %%
float(a[1])
# Out:
# 1.0

# %%
a[2] = 2.0
a
# Out:
# tensor([1., 1., 2.])

# %%
points = torch.tensor([[4.0, 1.0],
                       [5.0, 3.0],
                       [2.0, 1.0]
                       ])
points
# Out:
# tensor([[4., 1.],
#         [5., 3.],
#         [2., 1.]])

# %%
points.shape
# Out:
# torch.Size([3, 2])

# %%
points[1], points[1,1]
# Out:
# (tensor([5., 3.]), tensor(3.))

# %%
points[1:2, :]
# Out:
# tensor([[5., 3.]])

# %%
x = torch.tensor(
    [[1.0, 4.0, 8.0], [1.0, 4.0, 8.0], [1.0, 4.0, 8.0]], names=["row", "col"]
)

x
# Out:
# tensor([[1., 4., 8.],
#         [1., 4., 8.],
#         [1., 4., 8.]], names=('row', 'col'))

# %%
named_points = points.refine_names(...,"row", "column")
named_points
# Out:
# tensor([[4., 1.],
#         [5., 3.],
#         [2., 1.]], names=('row', 'column'))

# %%
x = torch.rand(3)
print(x.shape)
x.unsqueeze(0).shape
# Out:
# torch.Size([3])
# torch.Size([1, 3])

# %%
a = torch.rand(3, 4, names=('H', 'W'))
b = torch.rand(1, 4, names=('H', 'W'))

# a = torch.rand(3, 4, names=('H', 'W')) Error thename does not match
# b = torch.rand(1, 4, names=('W', 'H'))

a + b
#this named thing is an experimental thing
# Out:
# tensor([[0.4072, 1.3791, 0.8392, 1.6113],
#         [0.6573, 1.6680, 0.8240, 1.1801],
#         [0.1558, 1.0468, 0.6894, 0.9438]], names=('H', 'W'))

# %%
# Broadcasting is matching from right to left, if one of this is 1 then strech it up to n(other one)
# unsqueeze(d) is just adding a dimension at d index(between 2 dimension or front/back of 1 dimension)

# %%
n = torch.tensor([[1,2,3,1], [4,5,6,9], [8,2,3,3]])
n.shape, n.sum(0)
# Out:
# (torch.Size([3, 4]), tensor([13,  9, 12, 13]))

# %%
# k = torch.tensor([2,2])
k = torch.tensor([2.0,2])
k.dtype
# Out:
# torch.float32

# %%
# Indexing
points = torch.tensor([[4.0, 1.0], [5.0, 3.0], [2.0, 1.0]])
g = points.storage()
g[0]
# Out:
# 4.0

# %%
t = torch.tensor([[1,2,3,4], [9,9,9,9]])
print(t)
t.zero_()
print(t)
# Out:
# tensor([[1, 2, 3, 4],
#         [9, 9, 9, 9]])
# tensor([[0, 0, 0, 0],
#         [0, 0, 0, 0]])

# %%
t2 = t[1].clone()
t2
# Out:
# tensor([0, 0, 0, 0])

# %%
t3 = torch.tensor([[4,3,2,4], [3,4,0,0]]) 
p3 = t3[1,2]
print(p3.storage())
print(p3.storage_offset())
print(p3.stride())
# Out:
#  4
#  3
#  2
#  4
#  3
#  4
#  0
#  0
# [torch.storage.TypedStorage(dtype=torch.int64, device=cpu) of size 8]
# 6
# ()

# %%
b = torch.arange(9)
b
# Out:
# tensor([0, 1, 2, 3, 4, 5, 6, 7, 8])
