# %%
from transformers import pipeline

# %%
generator = pipeline("text-generation", model="gpt2")
generator("Hello, I'm a language model,", max_length=30)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  548MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# [{'generated_text': "Hello, I'm a language model, I'm a language model. I write languages that have a lot of code, but they're not always structured in a way that's consistent with other languages. And then the language is more flexible, and that is the way it works.\n\nAnother way to think of it is that a language is very much a model of reality. You're in a simulation, you're in a simulation. And then you're in a simulation of reality and you know that you're in the simulation. And then you're in a simulation of reality and you have a big idea about your reality, and then you're in a simulation and then you're in a simulation of reality. And then you're in a simulation of reality and you're in a simulation of reality. And then you're in a simulation and you have a large idea about your reality and you know that you're in the simulation and then you're in a simulation and you know that you're in the simulation and then you're in a simulation and you have a great idea about your reality.\n\nSo, it's very much a model of reality. And it's very much a model of this large idea that you bring to the table.\n\nBut that's not what I'm talking about here. It"}]
